# %%
import scipy.ndimage as ndimagegray()im = imread('../pictures/MV_HFV_012.jpg')im = im[60:]im = flipud(im)imshow(im)

# %%
print im
# Out:
# [[134 128 125 ...,  23  27  13] [132 128 126 ...,  11  12   1] [131 127 127 ...,   2   0   0] ...,  [118 117 110 ..., 147 132 144] [113 113 109 ..., 122 128 138] [117 119 117 ..., 132 145 129]]

# %%
his, bins = np.histogram(im, bins=255)

# %%
plot(his);

# %%
void = im < 50sand = np.logical_and(im >= 50, im <= 114)glass = im > 114

# %%
phases = void.astype(np.int) + 2*glass.astype(np.int) + 3*sand.astype(np.int)

# %%
imshow(phases)

# %%
gray()sand_op = ndimage.binary_opening(sand, iterations=2)imshow(sand_op)

# %%
sand_labels, sand_nb = ndimage.label(sand_op)sand_areas = np.array(ndimage.sum(sand_op, sand_labels, np.arange(sand_labels.max()+1)))mask = sand_areas > 100remove_small_sand = mask[sand_labels.ravel()].reshape(sand_labels.shape)

# %%
imshow(remove_small_sand)
