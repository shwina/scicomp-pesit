# %%
import pandas as pdimport numpy as np

# %%
cd ~/workspace/pesit/stats/
# Out:
# /home/ashwin/workspace/pesit/stats

# %%
run visualize.py

# %%
print countries
# Out:
# ['France', 'Germany', 'Australia', 'Egypt', 'Sweden', 'India', 'Greece', 'China', 'Nigeria', 'Netherlands']

# %%
for country in countries:    plot(years, cell.loc[country, years])

# %%
plt.show()
